# %% [markdown]
# # Dogs chase Cats and don't purr
# # (prepare dataset)

# %%
import pickle
from time import time
from discopy import Ty, Word
from discopy.grammar import brute_force, draw

# %%
s, n = Ty('s'), Ty('n')

# %%
dogs = Word('dogs', n)
chase = Word('chase', n.r @ s @ n.l)
cats =  Word('cats', n)
_and = Word('and', s.r @ n)
_or = Word('or', s.r @ n)
_do_not = Word("don't", n.r @ n)
purr = Word('purr', n.r @ s)

vocab = [dogs, chase, cats, _and, _or, _do_not, purr]

# %%
dataset_file_name = "dataset.csv"
serialized_sentences_folder = "serialized_sentences"

# %%
n_sentences = 100
gen = brute_force(*vocab)

#commenting to avoid override
#dataset_file = open(dataset_file_name, 'w')

print("Brute force search for grammatical sentences:\n")

start = time()
for i in range(n_sentences):
    
    #diagram object for sentence will be serialized in a binary file
    serialization_file = open(serialized_sentences_folder+'/'+str(i), 'wb')
    
    #next diagram in bruteforce
    diagram = next(gen)
    sentence = ' '.join(str(w) for w in diagram.boxes if isinstance(w, Word))
    print(diagram)
    draw(diagram, draw_type_labels=False)
    print()
    
    #update csv
    newline = '\n' if not i == n_sentences-1 else ''
    
    #dataset_file.write('\t'.join([str(i), sentence, newline]))
    
    #dump diagram object
    dump = pickle.dumps(diagram)
    serialization_file.write(dump)
    serialization_file.close()

#dataset_file.close()
print('\nDone !')
# Out:
# Brute force search for grammatical sentences:
#
# dogs >> Id(n) @ purr >> Cup(n, n.r) @ Id(s)
# cats >> Id(n) @ purr >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ dogs >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# dogs >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ cats >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# dogs >> Id(n) @ don't >> Id(n @ n.r @ n) @ purr >> Cup(n, n.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# cats >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ dogs >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# cats >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ cats >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# cats >> Id(n) @ don't >> Id(n @ n.r @ n) @ purr >> Cup(n, n.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ don't >> Id(n @ n.r @ n) @ chase >> Id(n @ n.r @ n @ n.r @ s @ n.l) @ dogs >> Cup(n, n.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# dogs >> Id(n) @ don't >> Id(n @ n.r @ n) @ chase >> Id(n @ n.r @ n @ n.r @ s @ n.l) @ cats >> Cup(n, n.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# dogs >> Id(n) @ don't >> Id(n @ n.r @ n) @ don't >> Id(n @ n.r @ n @ n.r @ n) @ purr >> Cup(n, n.r) @ Id(n @ n.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ purr >> Id(n @ n.r @ s) @ and >> Id(n @ n.r @ s @ s.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ purr >> Id(n @ n.r @ s) @ or >> Id(n @ n.r @ s @ s.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# cats >> Id(n) @ don't >> Id(n @ n.r @ n) @ chase >> Id(n @ n.r @ n @ n.r @ s @ n.l) @ dogs >> Cup(n, n.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# cats >> Id(n) @ don't >> Id(n @ n.r @ n) @ chase >> Id(n @ n.r @ n @ n.r @ s @ n.l) @ cats >> Cup(n, n.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# cats >> Id(n) @ don't >> Id(n @ n.r @ n) @ don't >> Id(n @ n.r @ n @ n.r @ n) @ purr >> Cup(n, n.r) @ Id(n @ n.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# cats >> Id(n) @ purr >> Id(n @ n.r @ s) @ and >> Id(n @ n.r @ s @ s.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# cats >> Id(n) @ purr >> Id(n @ n.r @ s) @ or >> Id(n @ n.r @ s @ s.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ dogs >> Id(n @ n.r @ s @ n.l @ n) @ and >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ dogs >> Id(n @ n.r @ s @ n.l @ n) @ or >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ cats >> Id(n @ n.r @ s @ n.l @ n) @ and >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ cats >> Id(n @ n.r @ s @ n.l @ n) @ or >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ don't >> Id(n @ n.r @ n) @ don't >> Id(n @ n.r @ n @ n.r @ n) @ chase >> Id(n @ n.r @ n @ n.r @ n @ n.r @ s @ n.l) @ dogs >> Cup(n, n.r) @ Id(n @ n.r @ n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# dogs >> Id(n) @ don't >> Id(n @ n.r @ n) @ don't >> Id(n @ n.r @ n @ n.r @ n) @ chase >> Id(n @ n.r @ n @ n.r @ n @ n.r @ s @ n.l) @ cats >> Cup(n, n.r) @ Id(n @ n.r @ n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# dogs >> Id(n) @ don't >> Id(n @ n.r @ n) @ don't >> Id(n @ n.r @ n @ n.r @ n) @ don't >> Id(n @ n.r @ n @ n.r @ n @ n.r @ n) @ purr >> Cup(n, n.r) @ Id(n @ n.r @ n @ n.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(n @ n.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ don't >> Id(n @ n.r @ n) @ purr >> Id(n @ n.r @ n @ n.r @ s) @ and >> Id(n @ n.r @ n @ n.r @ s @ s.r @ n) @ purr >> Cup(n, n.r) @ Id(n @ n.r @ s @ s.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ don't >> Id(n @ n.r @ n) @ purr >> Id(n @ n.r @ n @ n.r @ s) @ or >> Id(n @ n.r @ n @ n.r @ s @ s.r @ n) @ purr >> Cup(n, n.r) @ Id(n @ n.r @ s @ s.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ purr >> Id(n @ n.r @ s) @ and >> Id(n @ n.r @ s @ s.r @ n) @ chase >> Id(n @ n.r @ s @ s.r @ n @ n.r @ s @ n.l) @ dogs >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# dogs >> Id(n) @ purr >> Id(n @ n.r @ s) @ and >> Id(n @ n.r @ s @ s.r @ n) @ chase >> Id(n @ n.r @ s @ s.r @ n @ n.r @ s @ n.l) @ cats >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# dogs >> Id(n) @ purr >> Id(n @ n.r @ s) @ and >> Id(n @ n.r @ s @ s.r @ n) @ don't >> Id(n @ n.r @ s @ s.r @ n @ n.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ purr >> Id(n @ n.r @ s) @ or >> Id(n @ n.r @ s @ s.r @ n) @ chase >> Id(n @ n.r @ s @ s.r @ n @ n.r @ s @ n.l) @ dogs >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# dogs >> Id(n) @ purr >> Id(n @ n.r @ s) @ or >> Id(n @ n.r @ s @ s.r @ n) @ chase >> Id(n @ n.r @ s @ s.r @ n @ n.r @ s @ n.l) @ cats >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# dogs >> Id(n) @ purr >> Id(n @ n.r @ s) @ or >> Id(n @ n.r @ s @ s.r @ n) @ don't >> Id(n @ n.r @ s @ s.r @ n @ n.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# cats >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ dogs >> Id(n @ n.r @ s @ n.l @ n) @ and >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# cats >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ dogs >> Id(n @ n.r @ s @ n.l @ n) @ or >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# cats >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ cats >> Id(n @ n.r @ s @ n.l @ n) @ and >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# cats >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ cats >> Id(n @ n.r @ s @ n.l @ n) @ or >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# cats >> Id(n) @ don't >> Id(n @ n.r @ n) @ don't >> Id(n @ n.r @ n @ n.r @ n) @ chase >> Id(n @ n.r @ n @ n.r @ n @ n.r @ s @ n.l) @ dogs >> Cup(n, n.r) @ Id(n @ n.r @ n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# cats >> Id(n) @ don't >> Id(n @ n.r @ n) @ don't >> Id(n @ n.r @ n @ n.r @ n) @ chase >> Id(n @ n.r @ n @ n.r @ n @ n.r @ s @ n.l) @ cats >> Cup(n, n.r) @ Id(n @ n.r @ n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# cats >> Id(n) @ don't >> Id(n @ n.r @ n) @ don't >> Id(n @ n.r @ n @ n.r @ n) @ don't >> Id(n @ n.r @ n @ n.r @ n @ n.r @ n) @ purr >> Cup(n, n.r) @ Id(n @ n.r @ n @ n.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(n @ n.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# cats >> Id(n) @ don't >> Id(n @ n.r @ n) @ purr >> Id(n @ n.r @ n @ n.r @ s) @ and >> Id(n @ n.r @ n @ n.r @ s @ s.r @ n) @ purr >> Cup(n, n.r) @ Id(n @ n.r @ s @ s.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# cats >> Id(n) @ don't >> Id(n @ n.r @ n) @ purr >> Id(n @ n.r @ n @ n.r @ s) @ or >> Id(n @ n.r @ n @ n.r @ s @ s.r @ n) @ purr >> Cup(n, n.r) @ Id(n @ n.r @ s @ s.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# cats >> Id(n) @ purr >> Id(n @ n.r @ s) @ and >> Id(n @ n.r @ s @ s.r @ n) @ chase >> Id(n @ n.r @ s @ s.r @ n @ n.r @ s @ n.l) @ dogs >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# cats >> Id(n) @ purr >> Id(n @ n.r @ s) @ and >> Id(n @ n.r @ s @ s.r @ n) @ chase >> Id(n @ n.r @ s @ s.r @ n @ n.r @ s @ n.l) @ cats >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# cats >> Id(n) @ purr >> Id(n @ n.r @ s) @ and >> Id(n @ n.r @ s @ s.r @ n) @ don't >> Id(n @ n.r @ s @ s.r @ n @ n.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# cats >> Id(n) @ purr >> Id(n @ n.r @ s) @ or >> Id(n @ n.r @ s @ s.r @ n) @ chase >> Id(n @ n.r @ s @ s.r @ n @ n.r @ s @ n.l) @ dogs >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# cats >> Id(n) @ purr >> Id(n @ n.r @ s) @ or >> Id(n @ n.r @ s @ s.r @ n) @ chase >> Id(n @ n.r @ s @ s.r @ n @ n.r @ s @ n.l) @ cats >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# cats >> Id(n) @ purr >> Id(n @ n.r @ s) @ or >> Id(n @ n.r @ s @ s.r @ n) @ don't >> Id(n @ n.r @ s @ s.r @ n @ n.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ dogs >> Id(n @ n.r @ s @ n.l @ n) @ and >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ chase >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l) @ dogs >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l @ n) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# dogs >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ dogs >> Id(n @ n.r @ s @ n.l @ n) @ and >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ chase >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l) @ cats >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l @ n) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# dogs >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ dogs >> Id(n @ n.r @ s @ n.l @ n) @ and >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ don't >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ n @ n.r @ s) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ dogs >> Id(n @ n.r @ s @ n.l @ n) @ or >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ chase >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l) @ dogs >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l @ n) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# dogs >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ dogs >> Id(n @ n.r @ s @ n.l @ n) @ or >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ chase >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l) @ cats >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l @ n) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# dogs >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ dogs >> Id(n @ n.r @ s @ n.l @ n) @ or >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ don't >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ n @ n.r @ s) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ cats >> Id(n @ n.r @ s @ n.l @ n) @ and >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ chase >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l) @ dogs >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l @ n) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# dogs >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ cats >> Id(n @ n.r @ s @ n.l @ n) @ and >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ chase >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l) @ cats >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l @ n) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# dogs >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ cats >> Id(n @ n.r @ s @ n.l @ n) @ and >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ don't >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ n @ n.r @ s) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ cats >> Id(n @ n.r @ s @ n.l @ n) @ or >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ chase >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l) @ dogs >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l @ n) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# dogs >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ cats >> Id(n @ n.r @ s @ n.l @ n) @ or >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ chase >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l) @ cats >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l @ n) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# dogs >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ cats >> Id(n @ n.r @ s @ n.l @ n) @ or >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ don't >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ n @ n.r @ s) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ don't >> Id(n @ n.r @ n) @ chase >> Id(n @ n.r @ n @ n.r @ s @ n.l) @ dogs >> Id(n @ n.r @ n @ n.r @ s @ n.l @ n) @ and >> Id(n @ n.r @ n @ n.r @ s @ n.l @ n @ s.r @ n) @ purr >> Cup(n, n.r) @ Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ don't >> Id(n @ n.r @ n) @ chase >> Id(n @ n.r @ n @ n.r @ s @ n.l) @ dogs >> Id(n @ n.r @ n @ n.r @ s @ n.l @ n) @ or >> Id(n @ n.r @ n @ n.r @ s @ n.l @ n @ s.r @ n) @ purr >> Cup(n, n.r) @ Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ don't >> Id(n @ n.r @ n) @ chase >> Id(n @ n.r @ n @ n.r @ s @ n.l) @ cats >> Id(n @ n.r @ n @ n.r @ s @ n.l @ n) @ and >> Id(n @ n.r @ n @ n.r @ s @ n.l @ n @ s.r @ n) @ purr >> Cup(n, n.r) @ Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ don't >> Id(n @ n.r @ n) @ chase >> Id(n @ n.r @ n @ n.r @ s @ n.l) @ cats >> Id(n @ n.r @ n @ n.r @ s @ n.l @ n) @ or >> Id(n @ n.r @ n @ n.r @ s @ n.l @ n @ s.r @ n) @ purr >> Cup(n, n.r) @ Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ don't >> Id(n @ n.r @ n) @ don't >> Id(n @ n.r @ n @ n.r @ n) @ don't >> Id(n @ n.r @ n @ n.r @ n @ n.r @ n) @ chase >> Id(n @ n.r @ n @ n.r @ n @ n.r @ n @ n.r @ s @ n.l) @ dogs >> Cup(n, n.r) @ Id(n @ n.r @ n @ n.r @ n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(n @ n.r @ n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# dogs >> Id(n) @ don't >> Id(n @ n.r @ n) @ don't >> Id(n @ n.r @ n @ n.r @ n) @ don't >> Id(n @ n.r @ n @ n.r @ n @ n.r @ n) @ chase >> Id(n @ n.r @ n @ n.r @ n @ n.r @ n @ n.r @ s @ n.l) @ cats >> Cup(n, n.r) @ Id(n @ n.r @ n @ n.r @ n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(n @ n.r @ n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# dogs >> Id(n) @ don't >> Id(n @ n.r @ n) @ don't >> Id(n @ n.r @ n @ n.r @ n) @ don't >> Id(n @ n.r @ n @ n.r @ n @ n.r @ n) @ don't >> Id(n @ n.r @ n @ n.r @ n @ n.r @ n @ n.r @ n) @ purr >> Cup(n, n.r) @ Id(n @ n.r @ n @ n.r @ n @ n.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(n @ n.r @ n @ n.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(n @ n.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ don't >> Id(n @ n.r @ n) @ don't >> Id(n @ n.r @ n @ n.r @ n) @ purr >> Id(n @ n.r @ n @ n.r @ n @ n.r @ s) @ and >> Id(n @ n.r @ n @ n.r @ n @ n.r @ s @ s.r @ n) @ purr >> Cup(n, n.r) @ Id(n @ n.r @ n @ n.r @ s @ s.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(n @ n.r @ s @ s.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ don't >> Id(n @ n.r @ n) @ don't >> Id(n @ n.r @ n @ n.r @ n) @ purr >> Id(n @ n.r @ n @ n.r @ n @ n.r @ s) @ or >> Id(n @ n.r @ n @ n.r @ n @ n.r @ s @ s.r @ n) @ purr >> Cup(n, n.r) @ Id(n @ n.r @ n @ n.r @ s @ s.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(n @ n.r @ s @ s.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ don't >> Id(n @ n.r @ n) @ purr >> Id(n @ n.r @ n @ n.r @ s) @ and >> Id(n @ n.r @ n @ n.r @ s @ s.r @ n) @ chase >> Id(n @ n.r @ n @ n.r @ s @ s.r @ n @ n.r @ s @ n.l) @ dogs >> Cup(n, n.r) @ Id(n @ n.r @ s @ s.r @ n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# dogs >> Id(n) @ don't >> Id(n @ n.r @ n) @ purr >> Id(n @ n.r @ n @ n.r @ s) @ and >> Id(n @ n.r @ n @ n.r @ s @ s.r @ n) @ chase >> Id(n @ n.r @ n @ n.r @ s @ s.r @ n @ n.r @ s @ n.l) @ cats >> Cup(n, n.r) @ Id(n @ n.r @ s @ s.r @ n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# dogs >> Id(n) @ don't >> Id(n @ n.r @ n) @ purr >> Id(n @ n.r @ n @ n.r @ s) @ and >> Id(n @ n.r @ n @ n.r @ s @ s.r @ n) @ don't >> Id(n @ n.r @ n @ n.r @ s @ s.r @ n @ n.r @ n) @ purr >> Cup(n, n.r) @ Id(n @ n.r @ s @ s.r @ n @ n.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ don't >> Id(n @ n.r @ n) @ purr >> Id(n @ n.r @ n @ n.r @ s) @ or >> Id(n @ n.r @ n @ n.r @ s @ s.r @ n) @ chase >> Id(n @ n.r @ n @ n.r @ s @ s.r @ n @ n.r @ s @ n.l) @ dogs >> Cup(n, n.r) @ Id(n @ n.r @ s @ s.r @ n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# dogs >> Id(n) @ don't >> Id(n @ n.r @ n) @ purr >> Id(n @ n.r @ n @ n.r @ s) @ or >> Id(n @ n.r @ n @ n.r @ s @ s.r @ n) @ chase >> Id(n @ n.r @ n @ n.r @ s @ s.r @ n @ n.r @ s @ n.l) @ cats >> Cup(n, n.r) @ Id(n @ n.r @ s @ s.r @ n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# dogs >> Id(n) @ don't >> Id(n @ n.r @ n) @ purr >> Id(n @ n.r @ n @ n.r @ s) @ or >> Id(n @ n.r @ n @ n.r @ s @ s.r @ n) @ don't >> Id(n @ n.r @ n @ n.r @ s @ s.r @ n @ n.r @ n) @ purr >> Cup(n, n.r) @ Id(n @ n.r @ s @ s.r @ n @ n.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ purr >> Id(n @ n.r @ s) @ and >> Id(n @ n.r @ s @ s.r @ n) @ don't >> Id(n @ n.r @ s @ s.r @ n @ n.r @ n) @ chase >> Id(n @ n.r @ s @ s.r @ n @ n.r @ n @ n.r @ s @ n.l) @ dogs >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# dogs >> Id(n) @ purr >> Id(n @ n.r @ s) @ and >> Id(n @ n.r @ s @ s.r @ n) @ don't >> Id(n @ n.r @ s @ s.r @ n @ n.r @ n) @ chase >> Id(n @ n.r @ s @ s.r @ n @ n.r @ n @ n.r @ s @ n.l) @ cats >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# dogs >> Id(n) @ purr >> Id(n @ n.r @ s) @ and >> Id(n @ n.r @ s @ s.r @ n) @ don't >> Id(n @ n.r @ s @ s.r @ n @ n.r @ n) @ don't >> Id(n @ n.r @ s @ s.r @ n @ n.r @ n @ n.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ n @ n.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ n @ n.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(n @ n.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ purr >> Id(n @ n.r @ s) @ and >> Id(n @ n.r @ s @ s.r @ n) @ purr >> Id(n @ n.r @ s @ s.r @ n @ n.r @ s) @ and >> Id(n @ n.r @ s @ s.r @ n @ n.r @ s @ s.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s @ s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s @ s.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ purr >> Id(n @ n.r @ s) @ and >> Id(n @ n.r @ s @ s.r @ n) @ purr >> Id(n @ n.r @ s @ s.r @ n @ n.r @ s) @ or >> Id(n @ n.r @ s @ s.r @ n @ n.r @ s @ s.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s @ s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s @ s.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ purr >> Id(n @ n.r @ s) @ or >> Id(n @ n.r @ s @ s.r @ n) @ don't >> Id(n @ n.r @ s @ s.r @ n @ n.r @ n) @ chase >> Id(n @ n.r @ s @ s.r @ n @ n.r @ n @ n.r @ s @ n.l) @ dogs >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# dogs >> Id(n) @ purr >> Id(n @ n.r @ s) @ or >> Id(n @ n.r @ s @ s.r @ n) @ don't >> Id(n @ n.r @ s @ s.r @ n @ n.r @ n) @ chase >> Id(n @ n.r @ s @ s.r @ n @ n.r @ n @ n.r @ s @ n.l) @ cats >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# dogs >> Id(n) @ purr >> Id(n @ n.r @ s) @ or >> Id(n @ n.r @ s @ s.r @ n) @ don't >> Id(n @ n.r @ s @ s.r @ n @ n.r @ n) @ don't >> Id(n @ n.r @ s @ s.r @ n @ n.r @ n @ n.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ n @ n.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ n @ n.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(n @ n.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ purr >> Id(n @ n.r @ s) @ or >> Id(n @ n.r @ s @ s.r @ n) @ purr >> Id(n @ n.r @ s @ s.r @ n @ n.r @ s) @ and >> Id(n @ n.r @ s @ s.r @ n @ n.r @ s @ s.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s @ s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s @ s.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# dogs >> Id(n) @ purr >> Id(n @ n.r @ s) @ or >> Id(n @ n.r @ s @ s.r @ n) @ purr >> Id(n @ n.r @ s @ s.r @ n @ n.r @ s) @ or >> Id(n @ n.r @ s @ s.r @ n @ n.r @ s @ s.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s @ s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s @ s.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(s @ s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# cats >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ dogs >> Id(n @ n.r @ s @ n.l @ n) @ and >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ chase >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l) @ dogs >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l @ n) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# cats >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ dogs >> Id(n @ n.r @ s @ n.l @ n) @ and >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ chase >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l) @ cats >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l @ n) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# cats >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ dogs >> Id(n @ n.r @ s @ n.l @ n) @ and >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ don't >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ n @ n.r @ s) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# cats >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ dogs >> Id(n @ n.r @ s @ n.l @ n) @ or >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ chase >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l) @ dogs >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l @ n) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# cats >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ dogs >> Id(n @ n.r @ s @ n.l @ n) @ or >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ chase >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l) @ cats >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l @ n) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# cats >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ dogs >> Id(n @ n.r @ s @ n.l @ n) @ or >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ don't >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ n @ n.r @ s) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# cats >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ cats >> Id(n @ n.r @ s @ n.l @ n) @ and >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ chase >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l) @ dogs >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l @ n) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# cats >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ cats >> Id(n @ n.r @ s @ n.l @ n) @ and >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ chase >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l) @ cats >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l @ n) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# cats >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ cats >> Id(n @ n.r @ s @ n.l @ n) @ and >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ don't >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ n @ n.r @ s) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# cats >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ cats >> Id(n @ n.r @ s @ n.l @ n) @ or >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ chase >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l) @ dogs >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l @ n) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# cats >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ cats >> Id(n @ n.r @ s @ n.l @ n) @ or >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ chase >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l) @ cats >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s @ n.l @ n) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s @ n.l @ n) >> Cup(s, s.r) @ Id(n @ n.r @ s @ n.l @ n) >> Cup(n, n.r) @ Id(s @ n.l @ n) >> Id(s) @ Cup(n.l, n)
# cats >> Id(n) @ chase >> Id(n @ n.r @ s @ n.l) @ cats >> Id(n @ n.r @ s @ n.l @ n) @ or >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n) @ don't >> Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ n) @ purr >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ n @ n.r @ s) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# cats >> Id(n) @ don't >> Id(n @ n.r @ n) @ chase >> Id(n @ n.r @ n @ n.r @ s @ n.l) @ dogs >> Id(n @ n.r @ n @ n.r @ s @ n.l @ n) @ and >> Id(n @ n.r @ n @ n.r @ s @ n.l @ n @ s.r @ n) @ purr >> Cup(n, n.r) @ Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# cats >> Id(n) @ don't >> Id(n @ n.r @ n) @ chase >> Id(n @ n.r @ n @ n.r @ s @ n.l) @ dogs >> Id(n @ n.r @ n @ n.r @ s @ n.l @ n) @ or >> Id(n @ n.r @ n @ n.r @ s @ n.l @ n @ s.r @ n) @ purr >> Cup(n, n.r) @ Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# cats >> Id(n) @ don't >> Id(n @ n.r @ n) @ chase >> Id(n @ n.r @ n @ n.r @ s @ n.l) @ cats >> Id(n @ n.r @ n @ n.r @ s @ n.l @ n) @ and >> Id(n @ n.r @ n @ n.r @ s @ n.l @ n @ s.r @ n) @ purr >> Cup(n, n.r) @ Id(n @ n.r @ s @ n.l @ n @ s.r @ n @ n.r @ s) >> Cup(n, n.r) @ Id(s @ n.l @ n @ s.r @ n @ n.r @ s) >> Id(s) @ Cup(n.l, n) @ Id(s.r @ n @ n.r @ s) >> Cup(s, s.r) @ Id(n @ n.r @ s) >> Cup(n, n.r) @ Id(s)
# Done !

# %% [markdown]
# **We label the dataset by hand in a way that the truth value of the sentences are consistent**

# %%
sentences2truth_values = {}
with open(dataset_file_name) as fp:
    for line in fp:
        line = line.rstrip('\n')
        sent_id, sent, truth_val = line.split('\t')
        sentences2truth_values[sent] = int(truth_val)

print("True sentences:\n{}\n".format('\n'.join(sentence
    for sentence, truth_value in sentences2truth_values.items() if truth_value)))
print("False sentences:\n{}".format('\n'.join(sentence
    for sentence, truth_value in sentences2truth_values.items() if not truth_value)))
# Out:
# True sentences:
# cats purr
# dogs chase dogs
# dogs chase cats
# dogs don't purr
# cats chase cats
# cats don't chase dogs
# cats don't don't purr
# cats purr and purr
# cats purr or purr
# dogs chase dogs or purr
# dogs chase cats or purr
# dogs don't don't chase dogs
# dogs don't don't chase cats
# dogs don't don't don't purr
# dogs don't purr or purr
# dogs purr or chase dogs
# dogs purr or chase cats
# dogs purr or don't purr
# cats chase dogs or purr
# cats chase cats and purr
# cats chase cats or purr
# cats don't don't chase cats
# cats don't purr or purr
# cats purr and chase cats
# cats purr or chase dogs
# cats purr or chase cats
# cats purr or don't purr
# dogs chase dogs and chase dogs
# dogs chase dogs and chase cats
# dogs chase dogs and don't purr
# dogs chase dogs or chase dogs
# dogs chase dogs or chase cats
# dogs chase dogs or don't purr
# dogs chase cats and chase dogs
# dogs chase cats and chase cats
# dogs chase cats and don't purr
# dogs chase cats or chase dogs
# dogs chase cats or chase cats
# dogs chase cats or don't purr
# dogs don't purr and chase dogs
# dogs don't purr and chase cats
# dogs don't purr and don't purr
# dogs don't purr or chase dogs
# dogs don't purr or chase cats
# dogs don't purr or don't purr
# cats chase dogs or chase cats
# cats chase cats and chase cats
# cats chase cats or chase dogs
# cats chase cats or chase cats
# cats chase cats or don't purr
# cats don't chase dogs and purr
# cats don't chase dogs or purr
#
# False sentences:
# dogs purr
# cats chase dogs
# cats don't purr
# dogs don't chase dogs
# dogs don't chase cats
# dogs don't don't purr
# dogs purr and purr
# dogs purr or purr
# cats don't chase cats
# dogs chase dogs and purr
# dogs chase cats and purr
# dogs don't purr and purr
# dogs purr and chase dogs
# dogs purr and chase cats
# dogs purr and don't purr
# cats chase dogs and purr
# cats don't don't chase dogs
# cats don't don't don't purr
# cats don't purr and purr
# cats purr and chase dogs
# cats purr and don't purr
# dogs don't chase dogs and purr
# dogs don't chase dogs or purr
# dogs don't chase cats and purr
# dogs don't chase cats or purr
# dogs don't don't don't chase dogs
# dogs don't don't don't chase cats
# dogs don't don't don't don't purr
# dogs don't don't purr and purr
# dogs don't don't purr or purr
# dogs purr and don't chase dogs
# dogs purr and don't chase cats
# dogs purr and don't don't purr
# dogs purr and purr and purr
# dogs purr and purr or purr
# dogs purr or don't chase dogs
# dogs purr or don't chase cats
# dogs purr or don't don't purr
# dogs purr or purr and purr
# dogs purr or purr or purr
# cats chase dogs and chase dogs
# cats chase dogs and chase cats
# cats chase dogs and don't purr
# cats chase dogs or chase dogs
# cats chase dogs or don't purr
# cats chase cats and chase dogs
# cats chase cats and don't purr
# cats don't chase cats and purr
